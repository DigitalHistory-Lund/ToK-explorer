# %%
# !pip install -q tqdm pyriksdagen ipywidgets plotly

# %%
from pyparlaclarin.read import paragraph_iterator, speeches_with_name
from pyriksdagen.utils import protocol_iterators, download_corpus

from pathlib import Path
from queue import Queue
from lxml import etree
from tqdm.auto import tqdm

import progressbar
import pyriksdagen
import ipywidgets

import plotly.offline as pyo
import plotly.graph_objs as go
from typing import List, Tuple


import sqlite3
import re
import os

pyo.init_notebook_mode()

# %%
parser = etree.XMLParser(remove_blank_text=True)

data_dir = Path('.').resolve() / 'data'

# %%
if len([file for file in data_dir.iterdir() if file.is_file()]) < 25:
    print('Did not find metadata files. Downloading.')
    download_corpus(partitions=["persons"])

records_data_dir = data_dir / 'records'
if len([subdir for subdir in data_dir.iterdir() if subdir.is_dir()]) < 158:
    print('Did not find protocols files. Downloading.')
    download_corpus(partitions=["records"])

# %%
protocols = list(sorted(protocol_iterators(corpus_root="data/", start=1899, end=1941)))
print(len(protocols))

# %%
int(protocols[0].split('/')[1][:4])

# %%
def prepare_roots(protocols):
    for protocol in protocols:
        year = int(protocol.split('/')[1][:4])
        yield etree.parse(protocol, parser).getroot(), year

# %%
def process_root_queue(q: Queue):
    """
    TODO: Extract debate names
    TODO: Extract dates
    """
    while not q.empty():
        c, element, year = q.get()
        if (who:= element.get('who')) is not None:
            u_id = element.get([key for key in element.keys() if key.endswith('}id')][0])
            assert u_id
            prev = element.get('prev')
            nxt = element.get('next')
    
            text = '\n\n'.join(re.sub(r'\s+' ,' ', seg.text) for seg in element.getchildren())
            yield u_id, prev, nxt, text, who, year
        else:
            for child in element.getchildren():
                if (child.tag.endswith('note') or child.tag.endswith('seg')) and not bool(re.search(r'^\S+dag', child.text)):
                    continue
                q.put((c+1, child, year))

# %%
def extract_all_utterances(protocols):
    q = Queue()
    for root, year in prepare_roots(protocols):
        q.put((0,root, year))
    yield from process_root_queue(q)

# %%
all_utterances = []
for utterance in tqdm(extract_all_utterances(protocols), total=701_218): #total=5273785):
    all_utterances.append(utterance)

# %%
from itertools import islice
def batched(iterable, n, *, strict=False):
    # batched('ABCDEFG', 2) → AB CD EF G
    if n < 1:
        raise ValueError('n must be at least one')
    iterator = iter(iterable)
    while batch := tuple(islice(iterator, n)):
        if strict and len(batch) != n:
            raise ValueError('batched(): incomplete batch')
        yield batch

# %%
tmp_db = './tmp.db'
if os.path.exists(tmp_db):
    os.unlink(tmp_db)

with sqlite3.connect(tmp_db) as conn:
    cur = conn.cursor()
    cur.execute('CREATE TABLE utterance (id str primary key, prev text, next text, who text, year int)')
    # cur.execute("PRAGMA compile_options LIKE '%SQLITE_ENABLE_FTS5%';")
    cur.execute('CREATE VIRTUAL TABLE utterance_fts USING fts5(content)')
    cur.execute('CREATE index next_index on utterance(next)')
    cur.execute('CREATE index prev_index on utterance(prev)')
    cur.execute('CREATE index who_index on utterance(who)')
    cur.execute('CREATE index year_index on utterance(year)')

    data = []
    for batch in tqdm(batched(all_utterances, 50_000), total=len(all_utterances)//50_000):
        data = [{'id':u_id, 'prev':prev, 'next':nxt, 'content':text, 'who':who, 'year':year} for u_id, prev, nxt, text, who, year in batch]
        cur.executemany('INSERT INTO utterance_fts (content) values (:content)', data)
        cur.executemany('INSERT INTO utterance (id, prev, next, who, year) values (:id, :prev, :next, :who, :year)', data)
    
        conn.commit()
            
    # TODO: Add speaker metadata
# Out:
# 15it [00:36,  2.44s/it]

# %%
from collections import Counter

term_counter = Counter()

with sqlite3.connect(tmp_db) as conn:
    cur = conn.cursor()

    
    print(cur.execute('select count(*) from utterance_fts where content match "kvinna AND kvinnor"').fetchall())
    print(cur.execute('select count(*) from utterance_fts where content match "kvinna"').fetchall())
    print(cur.execute('select count(*) from utterance_fts where content match "kvinnor"').fetchall())
    print(cur.execute('select count(*) from utterance_fts where content match "kvinna OR kvinnor"').fetchall())
    print(cur.execute('select count(*) from utterance_fts where content match "kvinn*"').fetchall())

    term_counter = Counter((token.lower() for content in cur.execute('select content from utterance_fts where content match "kvinn*"')
        for token in content[0].split() if token.lower().startswith('kvinn')))
# Out:
# [(542,)]
# [(2126,)]
# [(3993,)]
# [(5577,)]
# [(10760,)]

# %%
term_counter.most_common()
# Out:
# [('kvinnliga', 4084),
#  ('kvinnor', 3497),
#  ('kvinnorna', 3035),
#  ('kvinnan', 2212),
#  ('kvinnor,', 1921),
#  ('kvinna', 1698),
#  ('kvinnans', 1509),
#  ('kvinnornas', 1113),
#  ('kvinnlig', 1015),
#  ('kvinna,', 952),
#  ('kvinnor.', 648),
#  ('kvinnorna,', 534),
#  ('kvinnors', 406),
#  ('kvinnan,', 323),
#  ('kvinnorna.', 306),
#  ('kvinnas', 295),
#  ('kvinna.', 213),
#  ('kvinnligt', 188),
#  ('kvinnan.', 168),
#  ('kvinnliga,', 69),
#  ('kvinnorösträtten', 62),
#  ('kvinnoförbundet', 56),
#  ('kvinnliga.', 54),
#  ('kvinnohåll', 37),
#  ('kvinnorösträttens', 36),
#  ('kvinnorösträtten,', 33),
#  ('kvinnlig,', 32),
#  ('kvinnorna?', 28),
#  ('kvinnor?', 25),
#  ('kvinnor;', 23),
#  ('kvinnoorganisationer', 22),
#  ('kvinnohåll,', 20),
#  ('kvinnlig.', 19),
#  ('kvinn-', 19),
#  ('kvinnofråga.', 18),
#  ('kvinnorörelsen', 18),
#  ('kvinnofrågan', 15),
#  ('kvinnor.»', 15),
#  ('kvinnorna:', 14),
#  ('kvinnoförbundets', 14),
#  ('kvinnornas.', 13),
#  ('kvinnorösträtten.', 13),
#  ('kvinna»', 12),
#  ('kvinnoförbund', 12),
#  ('kvinnor».', 11),
#  ('kvinnoföreningar', 11),
#  ('kvinnoorganisationer,', 11),
#  ('kvinnoarbetskommittén', 11),
#  ('kvinnovärlden', 10),
#  ('kvinnosaken', 9),
#  ('kvinnofråga', 9),
#  ('kvinnans,', 9),
#  ('kvinnoarbetet', 9),
#  ('kvinnoröster', 9),
#  ('kvinnor!', 8),
#  ('kvinnofrågan,', 8),
#  ('kvinnan?', 8),
#  ('kvinnoföreningen', 8),
#  ('kvinnoorganisationerna', 8),
#  ('kvinnokönet', 7),
#  ('kvinnosläktet', 7),
#  ('kvinnofråga,', 7),
#  ('kvinna».', 7),
#  ('kvinnornas,', 7),
#  ('kvinnoförbund,', 7),
#  ('kvinna.»', 7),
#  ('kvinnoförbundet,', 7),
#  ('kvinnoarbetskommitténs', 7),
#  ('kvinnodagsverke', 6),
#  ('kvinnlighet', 6),
#  ('kvinnans.', 6),
#  ('kvinnorösträttsfrågan', 6),
#  ('kvinnan;', 6),
#  ('kvinnor»,', 6),
#  ('kvinnoföreningar,', 6),
#  ('kvinnor:', 6),
#  ('kvinnorösträtt', 6),
#  ('kvinnosammanslutningar', 6),
#  ('kvinnorösterna', 6),
#  ('kvinnoförening,', 5),
#  ('kvinnokönet,', 5),
#  ('kvinnorna;', 5),
#  ('kvinnorna.»', 5),
#  ('kvinnoarbete', 5),
#  ('kvinnooch', 5),
#  ('kvinnoarbetet,', 5),
#  ('kvinna?', 5),
#  ('kvinnokretsar,', 5),
#  ('kvinnoorganisation,', 5),
#  ('kvinnoföreningarnas', 5),
#  ('kvinnan:', 4),
#  ('kvinnorörelsen,', 4),
#  ('kvinna;', 4),
#  ('kvinnligas,', 4),
#  ('kvinnokönets', 4),
#  ('kvinnorösträttsfrågan.', 4),
#  ('kvinnoklubben', 4),
#  ('kvinnovärlden,', 4),
#  ('kvinnorna!', 4),
#  ('kvinnodagsverken,', 4),
#  ('kvinnodagsverken', 4),
#  ('kvinnokongressen', 4),
#  ('kvinnor»', 4),
#  ('kvinnorösträtt,', 4),
#  ('kvinnofrågor', 4),
#  ('kvinnorösträttsrörelsens', 4),
#  ('kvinnorörelsens', 4),
#  ('kvinnoförbundet.', 4),
#  ('kvinnointresse', 4),
#  ('kvinna»,', 4),
#  ('kvinnohåll.', 4),
#  ('kvinnorösterna,', 4),
#  ('kvinnosynpunkt', 4),
#  ('kvinnogrupp,', 4),
#  ('kvinnosaksfrågan', 3),
#  ('kvinna:', 3),
#  ('kvinnan!', 3),
#  ('kvinnosidan,', 3),
#  ('kvinnoparti', 3),
#  ('kvinnoopinion', 3),
#  ('kvinnofrågans', 3),
#  ('kvinnors,', 3),
#  ('kvinnorörelsen.', 3),
#  ('kvinnan»', 3),
#  ('kvinnorösträtten?', 3),
#  ('kvinnkön', 3),
#  ('kvinnosakshåll', 3),
#  ('kvinnoorganisation', 3),
#  ('kvinnoskydd', 3),
#  ('kvinnoavdelningen', 3),
#  ("kvinnl'ga", 3),
#  ('kvinnosammanslutningar,', 3),
#  ('kvinnosidan', 3),
#  ('kvinnomöte', 3),
#  ('kvinnokretsar', 3),
#  ('kvinnoparti,', 3),
#  ('kvinnofrågor,', 3),
#  ('kvinnologik.', 3),
#  ('kvinnoförbund.', 3),
#  ('kvinnofängelset', 3),
#  ('kvinnoorganisationernas', 3),
#  ('kvinnoarbetet.', 3),
#  ('kvinnosammanslutningar.', 3),
#  ('kvinnoföreningars', 3),
#  ('kvinnoarbetskommittén,', 3),
#  ('kvinnoråd', 3),
#  ('kvinnoorganisationer.', 3),
#  ('kvinnosaken,', 2),
#  ('kvinnosakens', 2),
#  ('kvinnoförening', 2),
#  ('kvinnosaksfrågan,', 2),
#  ('kvinnlig?', 2),
#  ('kvinnoarbete,', 2),
#  ('kvinnofrågorna.', 2),
#  ('kvinnotyp', 2),
#  ('kvinnligheten', 2),
#  ('kvinnsdagsverken', 2),
#  ('kvinnokongress', 2),
#  ('kvinnosakskvinnornas', 2),
#  ('kvinnokraft', 2),
#  ('kvinnokongressens', 2),
#  ('kvinnorna»', 2),
#  ('kvinnoskyddet', 2),
#  ('kvinnofrågan.', 2),
#  ('kvinnomötet', 2),
#  ('kvinnokönet.', 2),
#  ('kvinnoklubbs', 2),
#  ('kvinna.>', 2),
#  ('kvinnor)', 2),
#  ('kvinnodagsverken.', 2),
#  ('kvinnsdagsverken.', 2),
#  ('kvinnsdagsverken,', 2),
#  ('kvinnorna.>', 2),
#  ('kvinnorösträttsfrågan,', 2),
#  ('kvinnliga;', 2),
#  ('kvinnoröster.', 2),
#  ('kvinnorörelsen?', 2),
#  ('kvinno-', 2),
#  ('kvinnoarbetets', 2),
#  ('kvinnar.', 2),
#  ('kvinnofriden', 2),
#  ('kvinnofridsstörare.', 2),
#  ('kvinnoföreningarna', 2),
#  ('kvinnan»,', 2),
#  ('kvinnorösträttsdebatten', 2),
#  ('kvinnosakskvinnor,', 2),
#  ('kvinnomöte,', 2),
#  ('kvinnosakskvinnorna,', 2),
#  ('kvinnokretsarnas»', 2),
#  ('kvinnosakshåll.', 2),
#  ('kvinnoopinion,', 2),
#  ('kvinnorösterna.', 2),
#  ('kvinnoavdelning', 2),
#  ('kvinnomajoritet', 2),
#  ('kvinnokraft,', 2),
#  ('kvinnointresse,', 2),
#  ('kvinnosaksfråga,', 2),
#  ('kvinnotidningen', 2),
#  ('kvinnogruppen', 2),
#  ('kvinnolönerna,', 2),
#  ('kvinnomöten,', 2),
#  ('kvinnoskändare.', 2),
#  ('kvinnoskändare', 2),
#  ('kvinnologik', 2),
#  ('kvinnoskydd,', 2),
#  ('kvinnoorganisationerna,', 2),
#  ('kvinnolöner,', 2),
#  ('kvinnosaksfråga.', 2),
#  ('kvinnoklubbar,', 2),
#  ('kvinna!', 2),
#  ('kvinnofråga?', 2),
#  ('kvinnorådet', 2),
#  ('kvinnosaksfrågan.', 1),
#  ('kvinnoandar,', 1),
#  ('kvinna»>,', 1),
#  ('kvinnoutbildningens', 1),
#  ('kvinnoemancipationen', 1),
#  ('kvinnobildningen', 1),
#  ('kvinnoundervisningen.', 1),
#  ('kvinnligas', 1),
#  ('kvinnotyp,', 1),
#  ('kvinnlighet,', 1),
#  ('kvinnfolk', 1),
#  ('kvinnosaksdiskussion,', 1),
#  ('kvinnolagstiftningens', 1),
#  ('kvinnoinflytandet', 1),
#  ('kvinnomöten', 1),
#  ('kvinnens', 1),
#  ('kvinnen', 1),
#  ('kvinnornags', 1),
#  ('kvinnorösträttsvänliga', 1),
#  ('kvinnolinjen', 1),
#  ('kvinnotypen', 1),
#  ('kvinnoundervisningen,', 1),
#  ('kvinnöföreningar', 1),
#  ('kvinnoras', 1),
#  ('kvinnoafdelning', 1),
#  ('kvinnorösträttsfrågans', 1),
#  ('kvinnornasjälfva,', 1),
#  ('kvinnogunst.', 1),
#  ('kvinnorösträttsfråga,', 1),
#  ('kvinnliga!', 1),
#  ('kvinnsperson.', 1),
#  ('kvinner', 1),
#  ('kvinnnorna', 1),
#  ('kvinnorua', 1),
#  ('kvinnokonferensen', 1),
#  ('kvinnosaks', 1),
#  ('kvinnokonferensen,', 1),
#  ('kvinnokonferens.', 1),
#  ('kvinnomna.', 1),
#  ('kvinnoemancipationsarbetet', 1),
#  ('kvinnovalkåren', 1),
#  ('kvinnofängelse.', 1),
#  ('kvinnoskyddslagstiftningen', 1),
#  ('kvinnoinspektionen', 1),
#  ('kvinnoskyddslagstiftning', 1),
#  ('kvinnan>', 1),
#  ('kvinnovänligt', 1),
#  ('kvinnovänlige.', 1),
#  ('kvinnokonferens,', 1),
#  ('kvinnorna),', 1),
#  ('kvinnoklubben.', 1),
#  ('kvinnohataren', 1),
#  ('kvinnorättshafveri»', 1),
#  ('kvinnosjukdomarna', 1),
#  ('kvinnoklubben,', 1),
#  ('kvinnsdagsverk,', 1),
#  ('kvinnofrågans,', 1),
#  ('kvinnorörelse,', 1),
#  ('kvinnosakssträfvandet.', 1),
#  ('kvinnomassan,', 1),
#  ('kvinnovinet.»', 1),
#  ('kvinnosaksfrågor', 1),
#  ('kvinnkön,', 1),
#  ('kvinnodagsverket', 1),
#  ('kvinnorösträttskongressen,', 1),
#  ('kvinnai', 1),
#  ('kvinnokörer', 1),
#  ('kvinnsdagsverke', 1),
#  ('kvinnsdagsverke.', 1),
#  ('kvinnsdagsverket', 1),
#  ('kvinnliga)', 1),
#  ('kvinnotitelreformen', 1),
#  ('kvinnosaksfrågor.', 1),
#  ('kvinnokongress,', 1),
#  ('kvinnligheten.', 1),
#  ('kvinnlighet.', 1),
#  ('kvinnohatare', 1),
#  ('kvinnosakskvinnan', 1),
#  ('kvinnorösträttsreform.', 1),
#  ('kvinnokongresserna', 1),
#  ('kvinnorösträttsländerna.', 1),
#  ('kvinnointressena', 1),
#  ('kvinnorösträttsrörelsen,', 1),
#  ('kvinnokraften', 1),
#  ('kvinnligt.', 1),
#  ('kvinnligt,', 1),
#  ('kvinnorösträtten;', 1),
#  ('kvinnorösträttsligt', 1),
#  ('kvinnoemancipation.', 1),
#  ('kvinnotidning', 1),
#  ('kvinnorösträttsdebatten,', 1),
#  ('kvinnliga?', 1),
#  ('kvinnokrafvet.', 1),
#  ('kvinnohår»', 1),
#  ('kvinnorösträttsreformen.', 1),
#  ('kvinnan».', 1),
#  ('kvinnoarbetet:', 1),
#  ('kvinnolagstiftning,', 1),
#  ('kvinnkönet.', 1),
#  ('kvinnkönet', 1),
#  ('kvinnoskyddslagstiftning,', 1),
#  ('kvinnoskyddsmän.»', 1),
#  ('kvinnors"an-', 1),
#  ('kvinnodagsverkena,', 1),
#  ('kvinnopensioneringen,', 1),
#  ('kvinnoklass,', 1),
#  ('kvinnopensioneringen.', 1),
#  ('kvinnoröst-', 1),
#  ('kvinnoparlament', 1),
#  ('kvinnorepresentation.', 1),
#  ('kvinnofigur,', 1),
#  ('kvinnda', 1),
#  ('kvinnofattigaste', 1),
#  ('kvinnofattiga', 1),
#  ('kvinnosaksarbetet', 1),
#  ('kvinnoöden.', 1),
#  ('kvinnofridstörare.', 1),
#  ('kvinnofridstörare,', 1),
#  ('kvinngarna', 1),
#  ('kvinnorösträttsfrår', 1),
#  ('kvinnonamn', 1),
#  ('kvinnoinsats', 1),
#  ('kvinnlioa', 1),
#  ('kvinnar', 1),
#  ('kvinnoår,', 1),
#  ('kvinnofridsstörande', 1),
#  ('kvinnofridstörarna,', 1),
#  ('kvinnofridens', 1),
#  ('kvinnofridsbrott', 1),
#  ('kvinnoskyddet,', 1),
#  ('kvinnrliga', 1),
#  ('kvinnans)', 1),
#  ('kvinno-.', 1),
#  ('kvinnan-modern,', 1),
#  ('kvinnosammanslutningen,', 1),
#  ('kvinnfolket.', 1),
#  ('kvinnohysterien,', 1),
#  ('kvinnovänlig', 1),
#  ('kvinnodemonstration', 1),
#  ('kvinnorösträttsreformen', 1),
#  ('kvinnobildningens', 1),
#  ('kvinnoöverskott,', 1),
#  ("kvinnans'", 1),
#  ('kvinnokrafter', 1),
#  ('kvinnorösträttan,', 1),
#  ('kvinnurnas', 1),
#  ('kvinnorösträttspetition,', 1),
#  ('kvinnnlig', 1),
#  ('kvinnokön', 1),
#  ('kvinnohjärtan,', 1),
#  ('kvinnorösträttsförkämpen', 1),
#  ('kvinnobildningen.', 1),
#  ('kvinnoansiktena', 1),
#  ('kvinnorna».', 1),
#  ('kvinnaps', 1),
#  ('kvinnonra,', 1),
#  ('kvinnornu,', 1),
#  ('kvinnliga.)', 1),
#  ('kvinnorösträttstrågan.', 1),
#  ('kvinnliga».', 1),
#  ('kvinn-1', 1),
#  ('kvinndel.', 1),
#  ('kvinnkvinnliga', 1),
#  ('kvinnsätta', 1),
#  ('kvinnsåsom', 1),
#  ('kvinnlämpar', 1),
#  ('kvinnkontrollera,', 1),
#  ('kvinnlämnad', 1),
#  ('kvinnbelungande', 1),
#  ('kvinnoraa', 1),
#  ('kvinnoviärlden,', 1),
#  ('kvinn', 1),
#  ('kvinnl.ga', 1),
#  ('kvinnosakförarnas', 1),
#  ('kvinnosakskvinnor.', 1),
#  ('kvinnofrid', 1),
#  ('kvinnorma', 1),
#  ('kvinnorepresentationer,', 1),
#  ('kvinnokretsar»', 1),
#  ('kvinnosakskärlek', 1),
#  ('kvinnosakssynpunkter', 1),
#  ('kvinnosakslag', 1),
#  ('kvinnohåll:', 1),
#  ('kvinnoföreningen.', 1),
#  ('kvinncr', 1),
#  ('kvinnorlämnade', 1),
#  ('kvinnogillena', 1),
#  ('kvinnoklubbarna,', 1),
#  ('kvinnomoralens', 1),
#  ('kvinnoflocken', 1),
#  ('kvinnbåde', 1),
#  ('kvinnornas;', 1),
#  ('kvinnovärld', 1),
#  ('kvinnorösträttsrö-', 1),
#  ('kvinnan:och', 1),
#  ('kvinnorösterna».', 1),
#  ('kvinnoagitation.', 1),
#  ('kvinnointressen', 1),
#  ('kvinnoområdet', 1),
#  ('kvinnor”,', 1),
#  ('kvinnarnas', 1),
#  ('kvinnoagitation,', 1),
#  ('kvinnoagitation', 1),
#  ('kvinnorna»,', 1),
#  ('kvinnogestalter,', 1),
#  ('kvinnogestalterna.', 1),
#  ('kvinnorörelse', 1),
#  ('kvinnoidealet,', 1),
#  ('kvinnokrav,', 1),
#  ('kvinnoutskott.', 1),
#  ('kvinnoemancipationsfrågan', 1),
#  ('kvinnopsykologiska', 1),
#  ('kvinnoinvasionen', 1),
#  ('kvinnogruppers', 1),
#  ('kvinnopetitioner,', 1),
#  ('kvinnmen', 1),
#  ("kvinn!'ga", 1),
#  ('kvinndeles', 1),
#  ('kvinnpå', 1),
#  ('kvinnbehandlas', 1),
#  ('kvinnfrån', 1),
#  ('kvinnreservanterna', 1),
#  ('kvinnicke', 1),
#  ('kvinnbörjan', 1),
#  ('kvinnmajoriteten', 1),
#  ('kvinnofriden.', 1),
#  ('kvinnting', 1),
#  ('kvinnopressen', 1),
#  ('kvinnogärningen', 1),
#  ('kvinnav', 1),
#  ('kvinnserna', 1),
#  ('kvinnorras', 1),
#  ('kvinnogenerationer,', 1),
#  ('kvinnfrankt', 1),
#  ('kvinnosakshåll,', 1),
#  ('kvinnsökning,', 1),
#  ('kvinnolönerna', 1),
#  ('kvinnosaksfråga', 1),
#  ('kvinnor”', 1),
#  ('kvinnohatare,', 1),
#  ('kvinnogrupper', 1),
#  ('kvinniga.', 1),
#  ('kvinnogruppens', 1),
#  ('kvinnosaksorganisationerna', 1),
#  ('kvinnoundervisningsfrågan', 1),
#  ('kvinnoemancipationen,', 1),
#  ('kvinnarna', 1),
#  ('kvinnoansikte,', 1),
#  ('kvinnoidealet!', 1),
#  ('kvinnoskän-', 1),
#  ('kvinnologik,', 1),
#  ('kvinnologiken', 1),
#  ('kvinnoröst', 1),
#  ('kvinnofängelser,', 1),
#  ('kvinna)', 1),
#  ('kvinnobhåll', 1),
#  ('kvinnokliniker,', 1),
#  ('kvinnosynpunkt,', 1),
#  ('kvinnoarmén', 1),
#  ('kvinnosakssynpunkt,', 1),
#  ('kvinnlig;', 1),
#  ('kvinnohåll.>', 1),
#  ('kvinnoskändare,', 1),
#  ('kvinnokliniker', 1),
#  ('kvinnokliniken', 1),
#  ('kvinnor."', 1),
#  ('kvinnoråd,', 1),
#  ('kvinnan,.', 1),
#  ('kvinnofridstöraren', 1),
#  ('kvinnovärldens', 1),
#  ('kvinnosläktet,', 1),
#  ('kvinnolöner', 1),
#  ('kvinnor-', 1),
#  ('kvinnokommission».', 1),
#  ('kvinnosaksrörelse,', 1),
#  ('kvinnoopinionen.', 1),
#  ('kvinnoorganisa-', 1),
#  ('kvinnovers,', 1),
#  ('kvinnoklinik.', 1),
#  ('kvinnoproblem.', 1),
#  ('kvinnorepresentanterna,', 1),
#  ('kvinnorganisationerna', 1),
#  ('kvinnopensionärerna,', 1),
#  ('kvinnokommittén', 1),
#  ('kvinnobhåll,', 1),
#  ('kvinnodistrikt', 1),
#  ('kvinnosaksreservation', 1),
#  ('kvinna?»', 1),
#  ('kvinnosammanslutningarnas', 1),
#  ('kvinnokategorien', 1),
#  ('kvinna»),', 1),
#  ('kvinnobeprisning.', 1),
#  ('kvinnosakskvinnor', 1),
#  ('kvinnoområden,', 1),
#  ('kvinnofientliga', 1),
#  ('kvinnokroppar.', 1),
#  ('kvinnoförbunden.', 1),
#  ('kvinnogestalterna', 1),
#  ('kvinnorra', 1),
#  ('kvinnoråds', 1),
#  ('kvinnoorganisations', 1),
#  ('kvinnoklubbarnas', 1),
#  ('kvinnoförbundet?', 1),
#  ('kvinnoförbundens', 1),
#  ('kvinnoförbunden', 1),
#  ('kvinnoantal', 1),
#  ('kvinnoantalet,', 1),
#  ('kvinnodistrikt,', 1),
#  ('kvinnodistrikts', 1),
#  ('kvinnodistriktets', 1),
#  ('kvinnoflykten,', 1),
#  ('kvinnoflykten', 1),
#  ('kvinnoorganisation.', 1),
#  ('kvinnoorganisationerna.', 1),
#  ('kvinnogrupperna', 1),
#  ('kvinnor!»', 1),
#  ('kvinnan-hustrun,', 1),
#  ('kvinnoopinion.', 1),
#  ('kvinnoorganisationer;', 1),
#  ('kvinnoförbunds', 1),
#  ('kvinnounderskottet', 1),
#  ('kvinnoförbunden,', 1),
#  ('kvinnosakskvinna,', 1),
#  ('kvinnosakskvinnorna', 1)]

# %%
def get_timeline(match_pattern: str) -> List[Tuple[int, int]]:
    with sqlite3.connect(tmp_db) as conn:
        cur = conn.cursor()
    
        return cur.execute(f'select year, count(*) from utterance as u join utterance_fts as uf on u.rowid == uf.rowid where content match "{match_pattern}" group by year').fetchall()

# %%
# Out:
# [(1899, 89),
#  (1900, 130),
#  (1901, 103),
#  (1902, 46),
#  (1903, 123),
#  (1904, 267),
#  (1905, 119),
#  (1906, 122),
#  (1907, 215),
#  (1908, 33),
#  (1909, 58),
#  (1910, 54),
#  (1911, 161),
#  (1912, 70),
#  (1913, 79),
#  (1914, 21),
#  (1915, 13),
#  (1916, 58),
#  (1917, 65),
#  (1918, 28),
#  (1919, 39),
#  (1920, 29),
#  (1921, 28),
#  (1922, 31),
#  (1923, 72),
#  (1924, 90),
#  (1925, 25),
#  (1926, 37),
#  (1927, 27),
#  (1928, 35),
#  (1929, 31),
#  (1930, 14),
#  (1931, 23),
#  (1932, 10),
#  (1933, 15),
#  (1934, 41),
#  (1935, 6),
#  (1936, 13),
#  (1937, 28),
#  (1938, 24),
#  (1939, 7),
#  (1940, 14),
#  (1941, 5)]

# %%
def get_or_timeline(keywords : List[str]) -> List[Tuple[int, int]]:
    pattern = ' OR '.join(keywords)
    return get_timeline(pattern)

# %%
kvinn = get_timeline('kvinn*')
kvinna = get_timeline('kvinna')
korv = get_timeline('korv')

# %%
def make_line(timeline, name):
    x,y = zip(*timeline)
    return go.Line(x=x, y=y, name=name)

# %%
queries = {
    "kvinn*" : ['kvinn*'],
    "kvinna" : ['kvinna'],
}
lines = [make_line(get_or_timeline(keywords), name) for name, keywords in queries.items()]
pyo.iplot(lines)
# Out:
# /home/matjoha/.virtualenvs/ulrika/lib/python3.10/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="6d96ff9a-99f7-4c5c-b68a-e7d752c1fca2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6d96ff9a-99f7-4c5c-b68a-e7d752c1fca2")) {                    Plotly.newPlot(                        "6d96ff9a-99f7-4c5c-b68a-e7d752c1fca2",                        [{"name":"kvinn*","x":[1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941],"y":[1,94,189,287,336,383,621,355,251,369,662,255,294,344,177,428,787,295,289,318,350,233,188,279,205,217,219,168,147,225,221,146,148,108,129,250,298,238,89,167],"type":"scatter"},{"name":"kvinna","x":[1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941],"y":[33,34,36,49,60,101,45,32,52,104,34,45,113,34,91,98,40,97,68,74,90,45,78,46,62,57,33,38,41,45,42,40,28,26,67,71,40,11,26],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"m ...
